# %% [markdown]
# # Módulo 1 — Cleaning Text Data
#
# Baseado no guia **Intro to NLP** do Kaggle. Usamos uma lista de SMS (spam/ham) criada aqui mesmo, no mesmo espírito do dataset clássico que o curso mostra.
#
# Este módulo é o primeiro de 4 interligados: aqui limpamos o texto e salvamos o resultado em `sms_clean.csv`, que o Módulo 2 (Feature Extraction) vai usar como ponto de partida.
#
# Tente resolver antes de olhar `exercicios_1_cleaning_text_data_solucoes.ipynb`.

# %%
import pandas as pd
import re

sms_data = [
    ("Hey, are we still on for lunch tomorrow?", "ham"),
    ("I'll call you when I get home from work.", "ham"),
    ("Can you send me the notes from today's class?", "ham"),
    ("Happy birthday! Hope you have an amazing day.", "ham"),
    ("Running a bit late, be there in 10 minutes.", "ham"),
    ("Thanks for the ride yesterday, really appreciated it.", "ham"),
    ("Don't forget to bring your laptop to the meeting.", "ham"),
    ("What time does the movie start tonight?", "ham"),
    ("I finished the report, sending it over now.", "ham"),
    ("Can you pick up milk on your way home?", "ham"),
    ("See you at the gym later!", "ham"),
    ("My flight got delayed by two hours.", "ham"),
    ("Let's catch up this weekend, it's been a while.", "ham"),
    ("I left my charger at your place, can I grab it tomorrow?", "ham"),
    ("Great job on the presentation today!", "ham"),
    ("Are you free for a call in the next hour?", "ham"),
    ("I think I left my keys in the car.", "ham"),
    ("The weather looks nice today, want to go for a walk?", "ham"),
    ("Sorry I missed your call, I was in a meeting.", "ham"),
    ("Can we reschedule our appointment to next week?", "ham"),
    ("Just landed, will text you when I'm home.", "ham"),
    ("Do you want anything from the store?", "ham"),
    ("The wifi password is on the fridge.", "ham"),
    ("I'm almost done with the assignment, just need to review it.", "ham"),
    ("Let me know if you need help moving this weekend.", "ham"),
    ("Thanks for lunch today, it was great catching up.", "ham"),
    ("Can you send me your address again?", "ham"),
    ("I'll be working from home tomorrow.", "ham"),
    ("The dentist appointment is at 3pm on Thursday.", "ham"),
    ("Loved the book you recommended, thank you!", "ham"),
    ("Can we talk about the project tomorrow morning?", "ham"),
    ("I'm heading out now, see you soon.", "ham"),
    ("Happy to help with the party planning.", "ham"),
    ("The package should arrive by Friday.", "ham"),
    ("Let's grab coffee before the meeting starts.", "ham"),
    ("I updated the spreadsheet with the new numbers.", "ham"),
    ("Can you confirm the meeting time for tomorrow?", "ham"),
    ("Thanks again for your help with the move.", "ham"),
    ("Can we meet at the coffee shop after work?", "ham"),
    ("I'll bring the documents to the meeting tomorrow.", "ham"),
    ("Call me back when you get a chance.", "ham"),
    ("Thanks for calling me back so quickly.", "ham"),
    ("See you at the meeting tomorrow morning.", "ham"),
    ("I'll text you the details of the meeting later.", "ham"),
    ("Can you call me when you're free?", "ham"),
    ("Thanks so much for helping with the project.", "ham"),
    ("I'll be at the office by 9am tomorrow.", "ham"),
    ("Let's plan the trip for next month.", "ham"),
    ("Can you send the file before the meeting starts?", "ham"),
    ("I appreciate you calling to check on me.", "ham"),
    ("WINNER!! You have been selected to receive a $900 prize reward. Call now to claim!", "spam"),
    ("URGENT! Your mobile number has won a 2000 pound prize GUARANTEED. Call 09061701461 now.", "spam"),
    ("Congratulations! You have been selected for a FREE iPhone. Click the link to claim your prize now.", "spam"),
    ("FreeMsg: Claim your free 3 hours talk time now, txt CLAIM to 86888.", "spam"),
    ("You have won a guaranteed 1000 pound cash prize! Text WIN to 80086 to claim.", "spam"),
    ("Get a FREE ringtone! Text TONE to 87131 now, only 1.50 per week.", "spam"),
    ("This is the 2nd attempt to contact you. You have won a 750 pound award, call 09066362231.", "spam"),
    ("Limited time offer! Buy one get one FREE on all products, click here now.", "spam"),
    ("Your account has been suspended. Verify your details immediately to avoid closure.", "spam"),
    ("Congrats! You qualify for a 5000 dollar cash loan approved instantly, apply now.", "spam"),
    ("Free entry into our 1000 dollar weekly draw, text ENTER to 12345 to join.", "spam"),
    ("Hot singles in your area want to chat! Click here to meet them now.", "spam"),
    ("You have been chosen for a FREE cruise vacation! Call now to book your spot.", "spam"),
    ("Reply YES to confirm your free gift card worth 100 dollars, act now before it expires.", "spam"),
    ("Text WIN now to claim your free cash prize before it expires.", "spam"),
    ("URGENT! Claim your free prize now, call this number immediately.", "spam"),
    ("You have won! Click now to claim your free cash reward.", "spam"),
    ("FREE prize waiting for you, call now to claim before time runs out.", "spam"),
    ("Congratulations, you won a free cash prize, text CLAIM now.", "spam"),
    ("URGENT! Call now to claim your free gift, offer ends today.", "spam"),
    ("You have been selected to win a free prize, click now to claim.", "spam"),
    ("Claim your free cash now! Urgent, call before it expires.", "spam"),
    ("Text CLAIM now for your free prize, urgent offer.", "spam"),
    ("Win free cash now! Call this number to claim your urgent prize.", "spam"),
]

sms = pd.DataFrame(sms_data, columns=["text", "label"])
sms.head()

# %% [markdown]
# ## 1.1 Explorar os dados
#
# Verifique o `shape` do DataFrame e a distribuição das classes com `value_counts()` e `value_counts(normalize=True)` (essa última mostra a proporção — repare que é uma base desbalanceada, a maioria é "ham").

# %%
# 1.1

# %% [markdown]
# ## 1.2 Lowercasing
#
# Crie a coluna `text_lower` com o texto de `text` todo em minúsculas (`.str.lower()`).

# %%
# 1.2

# %% [markdown]
# ## 1.3 Removendo pontuação e números
#
# Crie a coluna `text_no_punct` aplicando, em cada texto de `text_lower`, uma função que usa `re.sub` pra remover tudo que não for letra ou espaço (dica: `re.sub(r"[^a-z\s]", "", texto)`). Use `.apply()`.

# %%
# 1.3

# %% [markdown]
# ## 1.4 Tokenização
#
# Crie a coluna `tokens`, dividindo cada texto de `text_no_punct` em uma lista de palavras (`.str.split()`).

# %%
# 1.4

# %% [markdown]
# ## 1.5 Removendo stopwords
#
# Use a lista pronta de stopwords em inglês do scikit-learn: `from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS`.
#
# Crie a coluna `tokens_no_stopwords`, filtrando de cada lista em `tokens` as palavras que estão em `ENGLISH_STOP_WORDS` (use `.apply()` com uma função ou list comprehension).

# %%
# 1.5

# %% [markdown]
# ## 1.6 Stemming
#
# Use `from nltk.stem import PorterStemmer`. Crie a coluna `tokens_stemmed`, aplicando o stemmer (`stemmer.stem(palavra)`) em cada palavra de `tokens_no_stopwords`.

# %%
# 1.6

# %% [markdown]
# ## 1.7 Texto limpo final
#
# Crie a coluna `clean_text`, juntando as palavras de `tokens_stemmed` de volta em uma única string separada por espaço (`" ".join(lista)`).

# %%
# 1.7

# %% [markdown]
# ## 1.8 Salvar para o próximo módulo
#
# Salve apenas as colunas `label`, `text` e `clean_text` em um arquivo `sms_clean.csv` (`to_csv`, `index=False`), na mesma pasta deste notebook. O Módulo 2 vai carregar esse arquivo.

# %%
# 1.8
