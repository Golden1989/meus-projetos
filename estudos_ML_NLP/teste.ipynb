# %%
import pandas as pd

df = pd.DataFrame({
    "fruta": ["maçã", "banana", "uva"],
    "preco": [3.5, 2.0, 8.0]
})
print(df)
# Out:
#     fruta  preco
# 0    maçã    3.5
# 1  banana    2.0
# 2     uva    8.0
